# %%
# !pip3 install pytorch-msssim
# !pip3 install piqa

import torch
import torch.nn as nn
import torch.nn.functional as Fo
import torch.optim as optim
import zlib
import matplotlib.pyplot as plt
import numpy as np
from pytorch_msssim import SSIM
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import save_image
from PIL import Image
import warnings
import os

base_dir = os.getcwd()

# %% [markdown]
# <h1>Environment setup</h1>

# %%
import numpy as np
from scipy.stats import gamma
import matplotlib.pyplot as plt

# Network parameters
NUM_EDGE_SERVERS = 3
PACKET_SIZE = 1500  # bytes
UPDATE_FREQUENCY = 10  # Hz (updates per second)

# Bandwidth parameters (Gamma distribution)
BANDWIDTH_ALPHA = 5
BANDWIDTH_BETA = 10  # Mbps

# delays ( ms )
PROPAGATION_DELAY = 0.5

# Current Generation hardware
MODEL_512_CURRENT_GENERATION_MIN_DELAY = 5.6
MODEL_512_CURRENT_GENERATION_MAX_DELAY = 24.8

MODEL_256_CURRENT_GENERATION_MIN_DELAY = 4.6
MODEL_256_CURRENT_GENERATION_MAX_DELAY = 22.6

# Next Generation hardware
MODEL_512_NEXT_GENERATION_MIN_DELAY = 1.5
MODEL_512_NEXT_GENERATION_MAX_DELAY = 6.8

MODEL_256_NEXT_GENERATION_MIN_DELAY = 1.2
MODEL_256_NEXT_GENERATION_MAX_DELAY = 5.8


COMPRESSION_DELAY = 0 # Almost zero
DECOMPRESSION_DELAY = 0 # Almost zero

# Edge server parameters
SERVICE_RATE = 100  # tasks per second
CPU_CAPACITY = 1e12 # FLOPs per second
ALPHA = 1e-9 # Scaling factor for processing time
MAX_LOAD = 0.9

# Offloading trigger
OFFLOADING_THRESHOLD = 50 # ms

#Simulation time
SIMULATION_TIME = 10 #seconds
TIME_STEP = 1/UPDATE_FREQUENCY
NUM_QUANTIZATION_LEVELS = 256

LATENT_SIZE = 512  # Replace with your actual latent size
FIXED_INPUT_SIZE = 256

# %%
import numpy as np
from collections import deque
import random

class OffloadingAgent:
    def __init__(self, num_servers):
        self.num_servers = num_servers
        self.action_size = num_servers  # Removed local processing option

        self.state_size = num_servers * 3 + 3  # [bandwidth, latency, loss] + vehicle state
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995

        self.memory = deque(maxlen=1000)
        self.policy_model = None  # Placeholder for the trained model

    def get_state(self, network_stats, vehicle_state, server_loads):
        state = []
        for i in range(self.num_servers):
            state.extend([
                network_stats[i]['bandwidth'],
                network_stats[i]['latency'],
                network_stats[i]['packet_loss']
            ])
        state.extend([
            vehicle_state['battery'],
            vehicle_state['cpu_load'],
            vehicle_state['gpu_load']
        ])
        state.extend(server_loads)
        return np.array(state, dtype=np.float32)

    def act(self, state):
        """Epsilon-greedy action selection, excluding local processing"""
        if random.random() <= self.epsilon:
            return random.randint(0, self.action_size - 1)

        # Use heuristic if no model is trained
        if self.policy_model is None:
            network_stats = state[:self.num_servers * 3].reshape(self.num_servers, 3)
            latencies = network_stats[:, 1]  # latency is second entry
            return np.argmin(latencies)  # always choose best edge server

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def calculate_reward(self, latency, battery_consumption, cpu_load, gpu_load):
        r_latency = -latency
        r_resource = -(battery_consumption + cpu_load + gpu_load)
        return 0.7 * r_latency + 0.3 * r_resource

# %%
import random

def simulate_bandwidth():
    """Simulates bandwidth using a Gamma distribution."""
    bandwidth = gamma.rvs(BANDWIDTH_ALPHA, scale=BANDWIDTH_BETA)
    return bandwidth # in Mbps

def calculate_latency(bandwidth, queue_length, service_rate, compressed_data_size=25, gen='current', model_kind='512'): 
    """Calculates one-way communication latency with more realistic queueing"""
    # Transmission delay (same as before)
    transmission_delay = compressed_data_size / (bandwidth * 1e6) * 1000  # ms
    
    # More realistic queuing delay (M/M/1 model)
    arrival_rate = queue_length / TIME_STEP if TIME_STEP > 0 else 0
    utilization = arrival_rate / service_rate
    
    if utilization >= 1:
        queuing_delay = float('inf')
    else:
        queuing_delay = (utilization / (service_rate * (1 - utilization))) * 1000  # ms

    # print(f'queue delay: {queuing_delay}')
    
    # [Rest of your existing latency calculation...]
    if gen == 'current':
        if model_kind == '512':
            models_delay = random.uniform(MODEL_512_CURRENT_GENERATION_MIN_DELAY, MODEL_512_CURRENT_GENERATION_MAX_DELAY)
        else:
            models_delay = random.uniform(MODEL_256_CURRENT_GENERATION_MIN_DELAY, MODEL_256_CURRENT_GENERATION_MAX_DELAY)
    else:
        if model_kind == '512':
            models_delay = random.uniform(MODEL_512_NEXT_GENERATION_MIN_DELAY, MODEL_512_NEXT_GENERATION_MAX_DELAY)
        else:
            models_delay = random.uniform(MODEL_256_NEXT_GENERATION_MIN_DELAY, MODEL_256_NEXT_GENERATION_MAX_DELAY)

    # Total latency
    total_latency = PROPAGATION_DELAY + queuing_delay + transmission_delay + models_delay
    return total_latency

# %%
def calculate_server_load(queue_length, service_rate, time_step):
    """Calculate server load based on queue length and service rate"""
    if service_rate * time_step == 0:
        return 0.0
    return min(queue_length / (service_rate * time_step), MAX_LOAD)

# %% [markdown]
# <h1>Standard simulation</h1>

# %%
from PIL import Image
import torchvision.transforms as transforms

def main(compressed_data_size: int, gen: str, model_kind: str):
    print(f"\n--- Simulation: {gen.title()} Gen | Model {model_kind} | Size: {compressed_data_size}KB ---")
    
    # Initialize with zero load and empty queues
    server_loads = [0.0 for _ in range(NUM_EDGE_SERVERS)]
    queue_length = [0.0 for _ in range(NUM_EDGE_SERVERS)]  # Using float for more precise calculations

    # Create RL Agent
    agent = OffloadingAgent(NUM_EDGE_SERVERS)

    # Dummy vehicle state
    vehicle_state = {
        'battery': 0.8,
        'cpu_load': 0.3,
        'gpu_load': 0.2
    }

    n_steps = int(SIMULATION_TIME * UPDATE_FREQUENCY)

    for step in range(n_steps):
        # 1. Simulate Network Conditions
        bandwidths = [simulate_bandwidth() for _ in range(NUM_EDGE_SERVERS)]
        network_stats = []
        for i in range(NUM_EDGE_SERVERS):
            network_stats.append({
                'bandwidth': bandwidths[i],
                'latency': 0,  # Will be filled below
                'packet_loss': np.random.uniform(0.0, 0.1)
            })

        # 2. Calculate Latency to each server
        latencies = []
        for i in range(NUM_EDGE_SERVERS):
            latency = calculate_latency(
                bandwidths[i], queue_length[i], SERVICE_RATE, compressed_data_size, gen, model_kind
            )
            latencies.append(latency)
            network_stats[i]['latency'] = latency

        # 3. Build state and choose action
        state = agent.get_state(network_stats, vehicle_state, server_loads)
        action = agent.act(state)

        # 4. Display current step information
        print(f"\nStep: {step}")
        print(f"  Bandwidths: {[f'{bw:.2f}' for bw in bandwidths]} Mbps")
        print(f"  Latencies:  {[f'{lat:.2f}' for lat in latencies]} ms")
        print(f"  Server Loads: {[f'{load:.2f}' for load in server_loads]}")
        print(f"  Queue Lengths: {[f'{q:.1f}' for q in queue_length]}")

        # 5. Show selected action
        if action == NUM_EDGE_SERVERS:
            print(f"  ➤ Agent Action: LOCAL PROCESSING")
        else:
            print(f"  ➤ Agent Action: OFFLOAD to Edge Server {action}")

        # 6. Simulate task arrivals and processing
        for i in range(NUM_EDGE_SERVERS):
            new_tasks = np.random.poisson(lam=20 * TIME_STEP)
            queue_length[i] += new_tasks

            processed_tasks = min(queue_length[i], SERVICE_RATE * TIME_STEP)
            queue_length[i] -= processed_tasks

            server_loads[i] = calculate_server_load(queue_length[i], SERVICE_RATE, TIME_STEP)

        # Small noise to simulate load change
        server_loads = [
            min(max(0, load + np.random.uniform(-0.02, 0.02)), MAX_LOAD)
            for load in server_loads
        ]

# %% [markdown]
# <h1>512x512 Output Model Simulation With Current Generation Hardware</h1>

# %%
main(125, 'current', '512')
# Out:
# --- Simulation: Current Gen | Model 512 | Size: 125KB ---
#
# Step: 0
#   Bandwidths: ['24.90', '91.08', '76.30'] Mbps
#   Latencies:  ['22.61', '15.58', '15.44'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 1
#   Bandwidths: ['31.50', '32.55', '22.52'] Mbps
#   Latencies:  ['20.81', '13.32', '19.81'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 2
#   Bandwidths: ['31.46', '28.89', '76.32'] Mbps
#   Latencies:  ['7.64', '20.92', '12.48'] ms
#   Server Loads: ['0.01', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 3
#   Bandwidths: ['33.63', '47.47', '64.28'] Mbps
#   Latencies:  ['17.96', '21.45', '23.70'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 4
#   Bandwidths: ['124.81', '26.07', '16.90'] Mbps
#   Latencies:  ['25.29', '18.57', '10.07'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 5
#   Bandwidths: ['57.22', '73.33', '36.76'] Mbps
#   Latencies:  ['15.73', '8.90', '6.78'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 6
#   Bandwidths: ['21.58', '54.97', '64.71'] Mbps
#   Latencies:  ['7.75', '21.92', '9.31'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 7
#   Bandwidths: ['146.40', '93.08', '44.57'] Mbps
#   Latencies:  ['20.50', '18.58', '16.36'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 8
#   Bandwidths: ['76.60', '59.38', '21.32'] Mbps
#   Latencies:  ['17.22', '12.40', '15.89'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 9
#   Bandwidths: ['33.13', '32.80', '32.59'] Mbps
#   Latencies:  ['21.25', '8.94', '23.71'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 10
#   Bandwidths: ['68.30', '59.64', '75.53'] Mbps
#   Latencies:  ['8.16', '18.14', '7.34'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 11
#   Bandwidths: ['76.12', '67.45', '34.15'] Mbps
#   Latencies:  ['9.40', '8.46', '19.64'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 12
#   Bandwidths: ['58.12', '69.24', '58.44'] Mbps
#   Latencies:  ['15.89', '13.31', '22.19'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 13
#   Bandwidths: ['55.86', '76.83', '76.06'] Mbps
#   Latencies:  ['21.51', '6.66', '15.36'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 14
#   Bandwidths: ['29.93', '54.35', '30.62'] Mbps
#   Latencies:  ['16.77', '18.02', '15.80'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 15
#   Bandwidths: ['47.91', '49.41', '30.59'] Mbps
#   Latencies:  ['8.58', '12.35', '11.97'] ms
#   Server Loads: ['0.00', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 16
#   Bandwidths: ['61.86', '55.93', '113.65'] Mbps
#   Latencies:  ['24.52', '12.77', '22.30'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 17
#   Bandwidths: ['34.23', '40.28', '41.08'] Mbps
#   Latencies:  ['16.45', '20.66', '25.10'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 18
#   Bandwidths: ['45.17', '40.90', '56.37'] Mbps
#   Latencies:  ['10.01', '25.10', '21.69'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 19
#   Bandwidths: ['58.62', '86.26', '40.28'] Mbps
#   Latencies:  ['8.79', '13.44', '23.56'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 20
#   Bandwidths: ['24.64', '50.99', '72.41'] Mbps
#   Latencies:  ['10.41', '8.56', '9.64'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 21
#   Bandwidths: ['92.72', '28.45', '39.94'] Mbps
#   Latencies:  ['22.17', '24.67', '11.45'] ms
#   Server Loads: ['0.01', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 22
#   Bandwidths: ['63.54', '58.62', '48.04'] Mbps
#   Latencies:  ['9.20', '22.96', '24.01'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 23
#   Bandwidths: ['31.54', '96.72', '71.60'] Mbps
#   Latencies:  ['21.85', '23.13', '22.78'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 24
#   Bandwidths: ['31.26', '31.40', '69.93'] Mbps
#   Latencies:  ['19.86', '16.33', '13.56'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 25
#   Bandwidths: ['32.52', '53.21', '42.93'] Mbps
#   Latencies:  ['21.50', '17.95', '14.03'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 26
#   Bandwidths: ['55.66', '28.28', '24.25'] Mbps
#   Latencies:  ['13.43', '6.12', '14.94'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 27
#   Bandwidths: ['42.84', '28.74', '67.73'] Mbps
#   Latencies:  ['15.87', '12.14', '11.56'] ms
#   Server Loads: ['0.00', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 28
#   Bandwidths: ['34.01', '69.41', '76.33'] Mbps
#   Latencies:  ['8.91', '7.36', '13.97'] ms
#   Server Loads: ['0.01', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 29
#   Bandwidths: ['53.56', '47.20', '61.72'] Mbps
#   Latencies:  ['13.14', '22.57', '23.51'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 30
#   Bandwidths: ['44.75', '34.84', '41.16'] Mbps
#   Latencies:  ['12.34', '18.40', '14.57'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 31
#   Bandwidths: ['59.78', '72.05', '44.72'] Mbps
#   Latencies:  ['20.53', '22.02', '10.70'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 32
#   Bandwidths: ['34.21', '30.93', '51.01'] Mbps
#   Latencies:  ['23.09', '15.16', '10.15'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 33
#   Bandwidths: ['42.29', '33.91', '40.64'] Mbps
#   Latencies:  ['11.53', '10.42', '24.43'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 34
#   Bandwidths: ['30.02', '47.49', '82.05'] Mbps
#   Latencies:  ['24.01', '24.61', '23.58'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 35
#   Bandwidths: ['49.89', '30.56', '41.54'] Mbps
#   Latencies:  ['20.09', '15.07', '22.21'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 36
#   Bandwidths: ['35.47', '36.20', '42.82'] Mbps
#   Latencies:  ['18.07', '21.67', '19.18'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 37
#   Bandwidths: ['49.67', '41.73', '42.21'] Mbps
#   Latencies:  ['17.04', '15.60', '8.63'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 38
#   Bandwidths: ['96.30', '55.40', '25.05'] Mbps
#   Latencies:  ['17.60', '19.19', '17.03'] ms
#   Server Loads: ['0.00', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 39
#   Bandwidths: ['61.86', '85.84', '40.18'] Mbps
#   Latencies:  ['9.89', '17.98', '12.97'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 40
#   Bandwidths: ['63.40', '44.37', '86.44'] Mbps
#   Latencies:  ['6.99', '23.50', '20.64'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 41
#   Bandwidths: ['100.02', '49.12', '87.61'] Mbps
#   Latencies:  ['10.30', '11.85', '23.24'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 42
#   Bandwidths: ['37.41', '41.18', '25.87'] Mbps
#   Latencies:  ['14.38', '19.86', '6.69'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 43
#   Bandwidths: ['36.26', '37.94', '44.26'] Mbps
#   Latencies:  ['15.87', '19.60', '25.27'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 44
#   Bandwidths: ['77.48', '25.40', '58.88'] Mbps
#   Latencies:  ['24.48', '24.77', '16.57'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 45
#   Bandwidths: ['20.93', '62.63', '28.34'] Mbps
#   Latencies:  ['22.75', '25.28', '24.01'] ms
#   Server Loads: ['0.00', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 46
#   Bandwidths: ['36.23', '71.21', '68.33'] Mbps
#   Latencies:  ['12.54', '18.17', '24.76'] ms
#   Server Loads: ['0.01', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 47
#   Bandwidths: ['88.06', '38.54', '78.46'] Mbps
#   Latencies:  ['7.18', '11.04', '6.87'] ms
#   Server Loads: ['0.01', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 48
#   Bandwidths: ['43.59', '31.17', '45.96'] Mbps
#   Latencies:  ['11.68', '19.34', '8.85'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 49
#   Bandwidths: ['38.76', '8.50', '20.39'] Mbps
#   Latencies:  ['23.42', '10.13', '6.79'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 50
#   Bandwidths: ['41.97', '52.36', '37.47'] Mbps
#   Latencies:  ['8.95', '13.57', '20.62'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 51
#   Bandwidths: ['64.45', '64.00', '34.33'] Mbps
#   Latencies:  ['8.33', '16.05', '24.49'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 52
#   Bandwidths: ['44.82', '45.44', '50.86'] Mbps
#   Latencies:  ['17.09', '21.55', '14.56'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 53
#   Bandwidths: ['52.09', '30.98', '50.54'] Mbps
#   Latencies:  ['9.21', '22.29', '9.61'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 54
#   Bandwidths: ['42.28', '48.25', '87.97'] Mbps
#   Latencies:  ['17.65', '12.83', '15.05'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 55
#   Bandwidths: ['24.98', '63.87', '84.12'] Mbps
#   Latencies:  ['20.92', '16.08', '13.33'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 56
#   Bandwidths: ['35.40', '49.69', '72.28'] Mbps
#   Latencies:  ['20.39', '22.33', '21.94'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 57
#   Bandwidths: ['9.39', '58.49', '71.57'] Mbps
#   Latencies:  ['14.19', '17.32', '24.69'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 58
#   Bandwidths: ['42.50', '28.23', '74.17'] Mbps
#   Latencies:  ['20.69', '21.59', '14.91'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 59
#   Bandwidths: ['20.34', '28.37', '26.91'] Mbps
#   Latencies:  ['13.70', '16.81', '20.38'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 60
#   Bandwidths: ['21.54', '56.92', '84.07'] Mbps
#   Latencies:  ['8.14', '22.18', '10.27'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 61
#   Bandwidths: ['66.60', '54.24', '39.19'] Mbps
#   Latencies:  ['12.54', '17.92', '18.68'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 62
#   Bandwidths: ['46.33', '25.61', '51.70'] Mbps
#   Latencies:  ['18.92', '24.38', '20.49'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 63
#   Bandwidths: ['48.80', '66.34', '17.47'] Mbps
#   Latencies:  ['24.48', '23.84', '17.56'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 64
#   Bandwidths: ['53.11', '37.80', '39.55'] Mbps
#   Latencies:  ['21.32', '12.80', '23.95'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 65
#   Bandwidths: ['51.70', '31.31', '44.90'] Mbps
#   Latencies:  ['7.32', '12.40', '19.89'] ms
#   Server Loads: ['0.00', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 66
#   Bandwidths: ['77.16', '31.26', '24.02'] Mbps
#   Latencies:  ['9.81', '17.27', '23.78'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 67
#   Bandwidths: ['38.98', '30.72', '36.33'] Mbps
#   Latencies:  ['20.29', '13.71', '25.15'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 68
#   Bandwidths: ['75.27', '47.01', '36.57'] Mbps
#   Latencies:  ['18.80', '15.22', '18.27'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 69
#   Bandwidths: ['63.21', '55.91', '63.72'] Mbps
#   Latencies:  ['16.82', '16.93', '16.81'] ms
#   Server Loads: ['0.01', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 70
#   Bandwidths: ['57.52', '25.30', '86.55'] Mbps
#   Latencies:  ['21.28', '18.33', '13.36'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 71
#   Bandwidths: ['28.16', '75.00', '30.35'] Mbps
#   Latencies:  ['6.52', '20.39', '18.14'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 72
#   Bandwidths: ['53.25', '56.19', '31.34'] Mbps
#   Latencies:  ['22.58', '12.27', '8.27'] ms
#   Server Loads: ['0.02', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 73
#   Bandwidths: ['49.31', '34.24', '49.64'] Mbps
#   Latencies:  ['24.49', '22.16', '14.00'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 74
#   Bandwidths: ['27.15', '71.78', '63.76'] Mbps
#   Latencies:  ['10.53', '17.63', '22.93'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 75
#   Bandwidths: ['52.65', '80.31', '47.07'] Mbps
#   Latencies:  ['20.97', '14.45', '8.58'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 76
#   Bandwidths: ['16.56', '44.28', '60.13'] Mbps
#   Latencies:  ['18.82', '11.71', '21.88'] ms
#   Server Loads: ['0.02', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 77
#   Bandwidths: ['40.77', '24.46', '38.35'] Mbps
#   Latencies:  ['6.83', '25.16', '24.31'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 78
#   Bandwidths: ['54.90', '83.35', '46.56'] Mbps
#   Latencies:  ['14.90', '12.91', '25.29'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 79
#   Bandwidths: ['120.23', '32.22', '33.78'] Mbps
#   Latencies:  ['23.23', '9.06', '11.26'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 80
#   Bandwidths: ['33.38', '91.21', '23.96'] Mbps
#   Latencies:  ['7.29', '23.68', '8.61'] ms
#   Server Loads: ['0.02', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 81
#   Bandwidths: ['78.29', '58.46', '31.76'] Mbps
#   Latencies:  ['23.36', '7.08', '8.75'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 82
#   Bandwidths: ['68.17', '61.22', '45.44'] Mbps
#   Latencies:  ['13.31', '6.12', '21.84'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 83
#   Bandwidths: ['70.76', '37.22', '63.57'] Mbps
#   Latencies:  ['23.86', '6.60', '10.48'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 84
#   Bandwidths: ['66.39', '48.42', '58.49'] Mbps
#   Latencies:  ['19.76', '7.37', '9.36'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 85
#   Bandwidths: ['26.27', '42.73', '76.15'] Mbps
#   Latencies:  ['25.05', '24.77', '11.90'] ms
#   Server Loads: ['0.00', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 86
#   Bandwidths: ['4.98', '8.53', '20.36'] Mbps
#   Latencies:  ['24.69', '13.63', '15.49'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 87
#   Bandwidths: ['57.43', '48.57', '67.33'] Mbps
#   Latencies:  ['22.20', '6.42', '11.04'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 88
#   Bandwidths: ['18.39', '83.90', '68.38'] Mbps
#   Latencies:  ['25.04', '9.37', '20.76'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 89
#   Bandwidths: ['26.39', '56.01', '18.32'] Mbps
#   Latencies:  ['15.16', '11.52', '20.81'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 90
#   Bandwidths: ['24.16', '30.58', '59.35'] Mbps
#   Latencies:  ['24.85', '19.63', '14.29'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 91
#   Bandwidths: ['47.01', '38.26', '86.82'] Mbps
#   Latencies:  ['20.48', '20.47', '20.69'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 92
#   Bandwidths: ['44.71', '42.18', '32.58'] Mbps
#   Latencies:  ['15.54', '16.60', '10.81'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 93
#   Bandwidths: ['31.75', '98.64', '25.10'] Mbps
#   Latencies:  ['22.43', '25.26', '11.11'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 94
#   Bandwidths: ['41.80', '37.72', '40.06'] Mbps
#   Latencies:  ['19.07', '11.14', '7.24'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 95
#   Bandwidths: ['42.80', '34.11', '23.84'] Mbps
#   Latencies:  ['11.78', '9.29', '24.77'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 96
#   Bandwidths: ['68.86', '44.68', '60.66'] Mbps
#   Latencies:  ['9.32', '7.55', '15.10'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 97
#   Bandwidths: ['92.06', '36.66', '63.22'] Mbps
#   Latencies:  ['11.35', '6.21', '16.56'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 98
#   Bandwidths: ['66.33', '87.11', '68.35'] Mbps
#   Latencies:  ['24.80', '22.04', '18.69'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 99
#   Bandwidths: ['23.94', '60.84', '16.39'] Mbps
#   Latencies:  ['15.27', '14.12', '22.31'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1

# %% [markdown]
# <h1>512x512 Output Model Simulation With Next Generation Hardware</h1>

# %%
main(125, 'next', '512')
# Out:
# --- Simulation: Next Gen | Model 512 | Size: 125KB ---
#
# Step: 0
#   Bandwidths: ['33.29', '46.87', '51.88'] Mbps
#   Latencies:  ['6.91', '3.75', '6.28'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 1
#   Bandwidths: ['68.30', '45.58', '61.39'] Mbps
#   Latencies:  ['7.25', '2.02', '6.91'] ms
#   Server Loads: ['0.02', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 2
#   Bandwidths: ['59.87', '26.79', '53.22'] Mbps
#   Latencies:  ['3.73', '5.21', '6.60'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 3
#   Bandwidths: ['151.32', '33.30', '51.22'] Mbps
#   Latencies:  ['6.10', '5.73', '5.88'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 4
#   Bandwidths: ['67.61', '65.03', '95.98'] Mbps
#   Latencies:  ['5.59', '3.22', '4.27'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 5
#   Bandwidths: ['16.15', '30.65', '17.79'] Mbps
#   Latencies:  ['6.57', '4.45', '3.54'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 6
#   Bandwidths: ['39.85', '74.39', '44.23'] Mbps
#   Latencies:  ['4.66', '3.91', '6.35'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 7
#   Bandwidths: ['74.61', '51.78', '19.05'] Mbps
#   Latencies:  ['5.03', '4.38', '3.28'] ms
#   Server Loads: ['0.00', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 8
#   Bandwidths: ['44.51', '42.31', '46.31'] Mbps
#   Latencies:  ['5.00', '4.38', '2.76'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 9
#   Bandwidths: ['71.94', '76.13', '52.02'] Mbps
#   Latencies:  ['6.70', '5.14', '3.71'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 10
#   Bandwidths: ['43.21', '25.05', '33.06'] Mbps
#   Latencies:  ['2.66', '6.43', '2.67'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 11
#   Bandwidths: ['101.95', '60.29', '42.67'] Mbps
#   Latencies:  ['2.89', '7.26', '5.66'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 12
#   Bandwidths: ['48.25', '95.40', '35.92'] Mbps
#   Latencies:  ['2.51', '2.12', '3.35'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 13
#   Bandwidths: ['83.69', '74.34', '37.50'] Mbps
#   Latencies:  ['3.91', '5.98', '4.17'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 14
#   Bandwidths: ['37.81', '48.11', '54.07'] Mbps
#   Latencies:  ['2.56', '6.24', '5.28'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 15
#   Bandwidths: ['90.61', '53.72', '44.80'] Mbps
#   Latencies:  ['2.69', '5.78', '6.11'] ms
#   Server Loads: ['0.02', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 16
#   Bandwidths: ['42.20', '47.79', '58.40'] Mbps
#   Latencies:  ['2.53', '6.64', '5.44'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 17
#   Bandwidths: ['26.54', '60.17', '55.28'] Mbps
#   Latencies:  ['6.17', '5.51', '5.24'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 18
#   Bandwidths: ['40.15', '34.58', '27.09'] Mbps
#   Latencies:  ['4.73', '3.96', '3.97'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 19
#   Bandwidths: ['61.09', '38.85', '25.53'] Mbps
#   Latencies:  ['2.64', '2.46', '6.00'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 20
#   Bandwidths: ['40.46', '25.84', '89.05'] Mbps
#   Latencies:  ['6.14', '7.08', '6.25'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 21
#   Bandwidths: ['28.00', '52.59', '23.75'] Mbps
#   Latencies:  ['4.68', '4.09', '3.57'] ms
#   Server Loads: ['0.02', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 22
#   Bandwidths: ['35.19', '33.74', '48.18'] Mbps
#   Latencies:  ['3.86', '5.30', '6.06'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 23
#   Bandwidths: ['19.59', '63.16', '64.42'] Mbps
#   Latencies:  ['5.61', '4.07', '2.42'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 24
#   Bandwidths: ['28.85', '77.03', '37.52'] Mbps
#   Latencies:  ['3.22', '2.61', '6.94'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 25
#   Bandwidths: ['61.11', '19.04', '44.82'] Mbps
#   Latencies:  ['6.12', '4.05', '6.41'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 26
#   Bandwidths: ['83.80', '35.75', '46.38'] Mbps
#   Latencies:  ['2.16', '7.16', '2.58'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 27
#   Bandwidths: ['131.36', '36.28', '55.37'] Mbps
#   Latencies:  ['5.37', '6.30', '5.30'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 28
#   Bandwidths: ['38.61', '50.54', '68.84'] Mbps
#   Latencies:  ['3.42', '5.02', '3.88'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 29
#   Bandwidths: ['95.57', '101.87', '82.28'] Mbps
#   Latencies:  ['3.36', '5.63', '3.05'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 30
#   Bandwidths: ['52.82', '80.67', '39.73'] Mbps
#   Latencies:  ['3.01', '6.56', '5.88'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 31
#   Bandwidths: ['25.66', '70.94', '38.00'] Mbps
#   Latencies:  ['5.23', '5.13', '4.09'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 32
#   Bandwidths: ['94.13', '63.65', '46.18'] Mbps
#   Latencies:  ['3.22', '6.37', '4.36'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 33
#   Bandwidths: ['83.57', '97.72', '52.01'] Mbps
#   Latencies:  ['5.25', '6.69', '4.12'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 34
#   Bandwidths: ['32.81', '36.44', '25.97'] Mbps
#   Latencies:  ['2.23', '5.50', '3.18'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 35
#   Bandwidths: ['50.74', '20.48', '71.74'] Mbps
#   Latencies:  ['6.73', '4.85', '3.56'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 36
#   Bandwidths: ['38.00', '14.36', '68.58'] Mbps
#   Latencies:  ['6.25', '4.62', '6.80'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 37
#   Bandwidths: ['29.44', '85.45', '71.09'] Mbps
#   Latencies:  ['3.27', '5.61', '3.99'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 38
#   Bandwidths: ['43.66', '73.95', '20.38'] Mbps
#   Latencies:  ['6.28', '3.75', '2.12'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 39
#   Bandwidths: ['44.98', '30.25', '48.38'] Mbps
#   Latencies:  ['2.78', '2.01', '2.94'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 40
#   Bandwidths: ['72.67', '64.61', '26.33'] Mbps
#   Latencies:  ['3.33', '6.28', '6.85'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 41
#   Bandwidths: ['22.31', '30.88', '59.30'] Mbps
#   Latencies:  ['2.59', '2.13', '6.66'] ms
#   Server Loads: ['0.02', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 42
#   Bandwidths: ['31.68', '25.20', '42.36'] Mbps
#   Latencies:  ['5.53', '5.92', '3.64'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 43
#   Bandwidths: ['13.30', '74.27', '24.00'] Mbps
#   Latencies:  ['5.37', '3.39', '4.66'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 44
#   Bandwidths: ['31.12', '43.44', '19.80'] Mbps
#   Latencies:  ['7.23', '7.13', '7.13'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 45
#   Bandwidths: ['31.86', '52.23', '52.14'] Mbps
#   Latencies:  ['2.06', '2.37', '3.00'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 46
#   Bandwidths: ['36.18', '63.63', '52.82'] Mbps
#   Latencies:  ['2.84', '4.06', '5.95'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 47
#   Bandwidths: ['41.65', '73.97', '48.71'] Mbps
#   Latencies:  ['2.89', '2.59', '5.60'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 48
#   Bandwidths: ['33.14', '49.41', '61.44'] Mbps
#   Latencies:  ['4.04', '6.63', '6.08'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 49
#   Bandwidths: ['37.19', '26.03', '39.48'] Mbps
#   Latencies:  ['2.45', '3.34', '6.20'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 50
#   Bandwidths: ['26.31', '27.54', '35.65'] Mbps
#   Latencies:  ['4.99', '6.09', '5.88'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 51
#   Bandwidths: ['52.87', '38.53', '140.15'] Mbps
#   Latencies:  ['4.87', '2.32', '2.83'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 52
#   Bandwidths: ['38.90', '57.48', '40.99'] Mbps
#   Latencies:  ['3.88', '2.07', '2.92'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 53
#   Bandwidths: ['87.44', '52.84', '91.38'] Mbps
#   Latencies:  ['5.33', '4.92', '3.00'] ms
#   Server Loads: ['0.01', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 54
#   Bandwidths: ['83.13', '30.56', '72.67'] Mbps
#   Latencies:  ['2.13', '6.00', '6.87'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 55
#   Bandwidths: ['86.03', '38.52', '58.81'] Mbps
#   Latencies:  ['5.22', '5.00', '2.04'] ms
#   Server Loads: ['0.02', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 56
#   Bandwidths: ['37.66', '38.74', '53.30'] Mbps
#   Latencies:  ['7.16', '4.51', '6.00'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 57
#   Bandwidths: ['56.31', '66.58', '35.03'] Mbps
#   Latencies:  ['5.94', '3.21', '2.58'] ms
#   Server Loads: ['0.02', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 58
#   Bandwidths: ['43.45', '20.27', '38.97'] Mbps
#   Latencies:  ['2.50', '2.32', '5.69'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 59
#   Bandwidths: ['32.82', '39.28', '83.28'] Mbps
#   Latencies:  ['7.14', '2.66', '4.94'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 60
#   Bandwidths: ['18.70', '36.29', '44.83'] Mbps
#   Latencies:  ['3.61', '2.45', '5.22'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 61
#   Bandwidths: ['33.64', '18.96', '47.13'] Mbps
#   Latencies:  ['2.90', '3.08', '3.98'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 62
#   Bandwidths: ['36.34', '64.56', '137.16'] Mbps
#   Latencies:  ['5.06', '2.79', '3.18'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 63
#   Bandwidths: ['59.21', '66.18', '40.52'] Mbps
#   Latencies:  ['2.56', '3.17', '4.81'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 64
#   Bandwidths: ['52.30', '51.24', '35.12'] Mbps
#   Latencies:  ['5.54', '5.35', '6.81'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 65
#   Bandwidths: ['44.20', '45.16', '47.53'] Mbps
#   Latencies:  ['2.07', '3.65', '5.35'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 66
#   Bandwidths: ['33.69', '35.95', '96.53'] Mbps
#   Latencies:  ['3.36', '5.67', '3.31'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 67
#   Bandwidths: ['115.82', '33.07', '63.89'] Mbps
#   Latencies:  ['7.29', '3.82', '3.52'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 68
#   Bandwidths: ['38.28', '102.66', '37.24'] Mbps
#   Latencies:  ['5.09', '5.41', '2.45'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 69
#   Bandwidths: ['38.70', '89.82', '55.55'] Mbps
#   Latencies:  ['4.52', '6.00', '4.71'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 70
#   Bandwidths: ['28.29', '30.88', '45.52'] Mbps
#   Latencies:  ['2.72', '6.57', '6.07'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 71
#   Bandwidths: ['25.13', '23.50', '35.26'] Mbps
#   Latencies:  ['2.94', '7.23', '6.99'] ms
#   Server Loads: ['0.00', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 72
#   Bandwidths: ['73.21', '29.60', '52.02'] Mbps
#   Latencies:  ['2.73', '2.34', '5.25'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 73
#   Bandwidths: ['54.62', '61.98', '58.28'] Mbps
#   Latencies:  ['5.20', '3.09', '3.42'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 74
#   Bandwidths: ['34.74', '33.00', '35.03'] Mbps
#   Latencies:  ['2.10', '5.22', '6.87'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 75
#   Bandwidths: ['47.67', '35.23', '23.60'] Mbps
#   Latencies:  ['6.59', '4.14', '7.19'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 76
#   Bandwidths: ['71.45', '44.17', '41.31'] Mbps
#   Latencies:  ['5.06', '5.61', '5.38'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 77
#   Bandwidths: ['34.14', '28.97', '56.76'] Mbps
#   Latencies:  ['3.55', '3.64', '2.61'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 78
#   Bandwidths: ['64.71', '59.91', '45.14'] Mbps
#   Latencies:  ['2.35', '6.05', '2.53'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 79
#   Bandwidths: ['81.61', '29.50', '58.43'] Mbps
#   Latencies:  ['5.33', '3.14', '5.18'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 80
#   Bandwidths: ['70.29', '49.82', '45.08'] Mbps
#   Latencies:  ['5.23', '2.44', '2.83'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 81
#   Bandwidths: ['71.62', '70.73', '94.13'] Mbps
#   Latencies:  ['5.05', '2.79', '5.24'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 82
#   Bandwidths: ['55.86', '73.55', '40.54'] Mbps
#   Latencies:  ['2.48', '5.35', '2.42'] ms
#   Server Loads: ['0.02', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 83
#   Bandwidths: ['47.08', '31.39', '32.64'] Mbps
#   Latencies:  ['7.05', '3.19', '4.16'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 84
#   Bandwidths: ['83.78', '71.64', '54.00'] Mbps
#   Latencies:  ['5.76', '4.94', '6.40'] ms
#   Server Loads: ['0.02', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 85
#   Bandwidths: ['28.77', '104.77', '70.46'] Mbps
#   Latencies:  ['5.88', '2.17', '6.43'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 86
#   Bandwidths: ['96.87', '21.23', '38.90'] Mbps
#   Latencies:  ['4.66', '2.77', '4.13'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 87
#   Bandwidths: ['25.01', '67.61', '74.04'] Mbps
#   Latencies:  ['5.88', '2.73', '5.48'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 88
#   Bandwidths: ['49.61', '27.84', '50.37'] Mbps
#   Latencies:  ['3.58', '5.62', '7.20'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 89
#   Bandwidths: ['26.49', '39.44', '32.83'] Mbps
#   Latencies:  ['5.49', '6.19', '3.64'] ms
#   Server Loads: ['0.02', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 90
#   Bandwidths: ['81.78', '69.80', '32.87'] Mbps
#   Latencies:  ['2.95', '5.98', '4.71'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 91
#   Bandwidths: ['37.07', '33.62', '52.00'] Mbps
#   Latencies:  ['5.23', '3.73', '2.06'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 92
#   Bandwidths: ['40.95', '55.30', '43.46'] Mbps
#   Latencies:  ['3.39', '2.18', '6.04'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 93
#   Bandwidths: ['29.14', '47.72', '44.10'] Mbps
#   Latencies:  ['5.84', '4.05', '2.32'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 94
#   Bandwidths: ['46.84', '28.52', '39.56'] Mbps
#   Latencies:  ['3.41', '4.16', '2.18'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 95
#   Bandwidths: ['49.29', '11.69', '52.73'] Mbps
#   Latencies:  ['3.39', '5.61', '7.26'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 96
#   Bandwidths: ['113.53', '19.72', '48.41'] Mbps
#   Latencies:  ['2.45', '4.39', '3.76'] ms
#   Server Loads: ['0.00', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 97
#   Bandwidths: ['59.53', '77.32', '21.68'] Mbps
#   Latencies:  ['7.11', '4.66', '2.44'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 98
#   Bandwidths: ['82.54', '41.56', '37.20'] Mbps
#   Latencies:  ['6.02', '2.41', '5.07'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 99
#   Bandwidths: ['43.46', '40.21', '48.23'] Mbps
#   Latencies:  ['6.63', '4.71', '5.07'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0

# %% [markdown]
# <h1>256x256 Output Model Simulation With Current Generation Hardware</h1>

# %%
main(25, 'current', '256')
# Out:
# --- Simulation: Current Gen | Model 256 | Size: 25KB ---
#
# Step: 0
#   Bandwidths: ['47.99', '43.43', '53.04'] Mbps
#   Latencies:  ['12.61', '15.34', '16.68'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 1
#   Bandwidths: ['53.82', '47.76', '66.91'] Mbps
#   Latencies:  ['15.58', '14.57', '21.91'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 2
#   Bandwidths: ['24.90', '22.69', '27.62'] Mbps
#   Latencies:  ['17.14', '16.96', '12.86'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 3
#   Bandwidths: ['97.05', '64.11', '39.51'] Mbps
#   Latencies:  ['10.82', '21.23', '9.29'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 4
#   Bandwidths: ['89.69', '45.22', '34.43'] Mbps
#   Latencies:  ['22.23', '19.63', '9.00'] ms
#   Server Loads: ['0.01', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 5
#   Bandwidths: ['32.36', '41.87', '64.76'] Mbps
#   Latencies:  ['20.24', '15.05', '9.19'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 6
#   Bandwidths: ['38.04', '38.13', '40.40'] Mbps
#   Latencies:  ['18.56', '13.67', '8.80'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 7
#   Bandwidths: ['21.72', '73.70', '54.25'] Mbps
#   Latencies:  ['19.38', '13.94', '15.39'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 8
#   Bandwidths: ['52.33', '35.73', '50.69'] Mbps
#   Latencies:  ['15.00', '22.61', '15.08'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 9
#   Bandwidths: ['50.04', '59.49', '71.08'] Mbps
#   Latencies:  ['16.47', '9.75', '10.71'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 10
#   Bandwidths: ['50.06', '15.76', '43.06'] Mbps
#   Latencies:  ['19.58', '23.09', '17.26'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 11
#   Bandwidths: ['54.69', '58.97', '116.53'] Mbps
#   Latencies:  ['10.78', '7.07', '11.43'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 12
#   Bandwidths: ['54.53', '63.04', '47.49'] Mbps
#   Latencies:  ['18.85', '14.34', '17.75'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 13
#   Bandwidths: ['87.77', '54.74', '74.47'] Mbps
#   Latencies:  ['22.86', '7.50', '14.74'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 14
#   Bandwidths: ['66.64', '43.54', '41.15'] Mbps
#   Latencies:  ['7.97', '7.91', '16.61'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 15
#   Bandwidths: ['41.96', '58.03', '34.70'] Mbps
#   Latencies:  ['9.21', '10.71', '12.43'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 16
#   Bandwidths: ['46.82', '45.46', '101.42'] Mbps
#   Latencies:  ['5.43', '10.15', '7.74'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 17
#   Bandwidths: ['32.86', '42.64', '25.91'] Mbps
#   Latencies:  ['15.03', '13.70', '11.26'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 18
#   Bandwidths: ['113.08', '81.54', '54.63'] Mbps
#   Latencies:  ['7.51', '6.45', '13.41'] ms
#   Server Loads: ['0.02', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 19
#   Bandwidths: ['24.33', '46.55', '83.67'] Mbps
#   Latencies:  ['21.01', '8.82', '12.68'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 20
#   Bandwidths: ['19.93', '44.37', '26.36'] Mbps
#   Latencies:  ['9.76', '5.18', '16.23'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 21
#   Bandwidths: ['65.90', '36.54', '79.69'] Mbps
#   Latencies:  ['10.71', '9.89', '16.26'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 22
#   Bandwidths: ['39.79', '34.90', '37.81'] Mbps
#   Latencies:  ['10.10', '18.70', '22.92'] ms
#   Server Loads: ['0.01', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 23
#   Bandwidths: ['52.64', '59.84', '80.19'] Mbps
#   Latencies:  ['19.78', '17.05', '6.14'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 24
#   Bandwidths: ['23.25', '15.09', '89.56'] Mbps
#   Latencies:  ['20.13', '12.89', '14.79'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 25
#   Bandwidths: ['58.12', '65.46', '83.74'] Mbps
#   Latencies:  ['10.12', '14.90', '6.21'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 26
#   Bandwidths: ['81.37', '74.58', '82.56'] Mbps
#   Latencies:  ['16.32', '14.94', '8.70'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 27
#   Bandwidths: ['27.10', '35.75', '71.27'] Mbps
#   Latencies:  ['14.59', '11.87', '7.55'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 28
#   Bandwidths: ['58.05', '39.89', '28.40'] Mbps
#   Latencies:  ['5.85', '18.82', '9.06'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 29
#   Bandwidths: ['25.51', '34.96', '18.09'] Mbps
#   Latencies:  ['5.91', '14.61', '14.52'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 30
#   Bandwidths: ['37.81', '40.70', '35.18'] Mbps
#   Latencies:  ['9.35', '20.25', '16.36'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 31
#   Bandwidths: ['70.15', '16.08', '45.51'] Mbps
#   Latencies:  ['13.28', '22.23', '17.25'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 32
#   Bandwidths: ['54.22', '59.37', '36.82'] Mbps
#   Latencies:  ['15.76', '7.27', '10.27'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 33
#   Bandwidths: ['53.51', '49.15', '86.19'] Mbps
#   Latencies:  ['19.89', '20.24', '21.65'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 34
#   Bandwidths: ['43.85', '103.69', '66.74'] Mbps
#   Latencies:  ['15.27', '11.02', '13.94'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 35
#   Bandwidths: ['51.83', '51.45', '25.09'] Mbps
#   Latencies:  ['15.72', '10.08', '20.82'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 36
#   Bandwidths: ['39.11', '35.80', '17.89'] Mbps
#   Latencies:  ['12.35', '22.16', '22.97'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 37
#   Bandwidths: ['19.75', '54.32', '44.35'] Mbps
#   Latencies:  ['19.24', '15.28', '5.92'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 38
#   Bandwidths: ['34.69', '64.91', '41.16'] Mbps
#   Latencies:  ['12.94', '10.84', '6.12'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 39
#   Bandwidths: ['48.21', '48.64', '36.48'] Mbps
#   Latencies:  ['21.22', '18.00', '11.68'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 40
#   Bandwidths: ['28.08', '63.90', '38.41'] Mbps
#   Latencies:  ['9.70', '17.13', '10.54'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 41
#   Bandwidths: ['30.57', '58.36', '42.49'] Mbps
#   Latencies:  ['15.05', '9.47', '13.12'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 42
#   Bandwidths: ['53.52', '24.40', '95.49'] Mbps
#   Latencies:  ['16.87', '6.60', '5.74'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 43
#   Bandwidths: ['76.43', '53.63', '48.41'] Mbps
#   Latencies:  ['14.93', '15.26', '14.49'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 44
#   Bandwidths: ['39.52', '57.65', '18.29'] Mbps
#   Latencies:  ['10.84', '11.38', '18.59'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 45
#   Bandwidths: ['27.85', '22.12', '43.05'] Mbps
#   Latencies:  ['14.86', '22.41', '18.87'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 46
#   Bandwidths: ['45.74', '61.76', '101.36'] Mbps
#   Latencies:  ['19.12', '13.57', '21.15'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 47
#   Bandwidths: ['11.72', '40.28', '69.54'] Mbps
#   Latencies:  ['18.10', '11.54', '8.78'] ms
#   Server Loads: ['0.02', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 48
#   Bandwidths: ['52.90', '31.92', '70.49'] Mbps
#   Latencies:  ['9.83', '16.47', '6.68'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 49
#   Bandwidths: ['56.69', '80.90', '55.58'] Mbps
#   Latencies:  ['16.43', '20.46', '20.68'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 50
#   Bandwidths: ['48.15', '40.78', '14.73'] Mbps
#   Latencies:  ['13.07', '22.89', '13.08'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 51
#   Bandwidths: ['24.57', '24.63', '46.56'] Mbps
#   Latencies:  ['5.56', '10.66', '12.90'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 52
#   Bandwidths: ['81.96', '12.85', '22.20'] Mbps
#   Latencies:  ['13.00', '8.39', '11.93'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 53
#   Bandwidths: ['63.58', '50.20', '51.37'] Mbps
#   Latencies:  ['6.91', '15.04', '15.59'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 54
#   Bandwidths: ['23.54', '20.29', '45.84'] Mbps
#   Latencies:  ['22.39', '12.02', '18.41'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 55
#   Bandwidths: ['41.30', '61.04', '30.60'] Mbps
#   Latencies:  ['5.65', '16.25', '7.64'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 56
#   Bandwidths: ['25.28', '34.40', '43.47'] Mbps
#   Latencies:  ['16.06', '22.36', '15.04'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 57
#   Bandwidths: ['28.72', '54.53', '35.50'] Mbps
#   Latencies:  ['12.77', '15.26', '8.44'] ms
#   Server Loads: ['0.00', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 58
#   Bandwidths: ['34.31', '34.31', '55.01'] Mbps
#   Latencies:  ['19.90', '9.79', '21.41'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 59
#   Bandwidths: ['50.83', '42.23', '26.01'] Mbps
#   Latencies:  ['20.27', '19.32', '15.75'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 60
#   Bandwidths: ['67.50', '83.76', '57.21'] Mbps
#   Latencies:  ['17.16', '14.07', '19.08'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 61
#   Bandwidths: ['40.25', '49.17', '17.99'] Mbps
#   Latencies:  ['17.66', '8.96', '5.67'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 62
#   Bandwidths: ['15.46', '126.82', '44.86'] Mbps
#   Latencies:  ['6.27', '8.65', '13.34'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 63
#   Bandwidths: ['37.93', '20.11', '37.57'] Mbps
#   Latencies:  ['10.60', '12.51', '17.47'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 64
#   Bandwidths: ['66.94', '52.42', '30.60'] Mbps
#   Latencies:  ['21.54', '18.77', '21.39'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 65
#   Bandwidths: ['14.75', '47.92', '34.10'] Mbps
#   Latencies:  ['20.66', '18.91', '16.40'] ms
#   Server Loads: ['0.02', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 66
#   Bandwidths: ['55.56', '58.97', '69.81'] Mbps
#   Latencies:  ['14.16', '10.91', '8.61'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 67
#   Bandwidths: ['30.30', '33.91', '26.02'] Mbps
#   Latencies:  ['18.93', '19.33', '14.40'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 68
#   Bandwidths: ['56.69', '39.63', '87.40'] Mbps
#   Latencies:  ['11.96', '18.52', '15.55'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 69
#   Bandwidths: ['73.76', '81.77', '39.97'] Mbps
#   Latencies:  ['19.81', '14.54', '7.03'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 70
#   Bandwidths: ['41.13', '31.76', '89.76'] Mbps
#   Latencies:  ['14.35', '5.67', '10.24'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 71
#   Bandwidths: ['25.65', '39.76', '104.87'] Mbps
#   Latencies:  ['17.88', '17.61', '16.85'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 72
#   Bandwidths: ['30.96', '39.50', '29.89'] Mbps
#   Latencies:  ['11.70', '7.62', '9.45'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 73
#   Bandwidths: ['43.96', '44.69', '46.62'] Mbps
#   Latencies:  ['21.64', '17.70', '10.01'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 74
#   Bandwidths: ['86.90', '37.20', '99.12'] Mbps
#   Latencies:  ['21.00', '21.92', '12.69'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 75
#   Bandwidths: ['42.10', '39.10', '70.90'] Mbps
#   Latencies:  ['9.02', '23.06', '5.65'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 76
#   Bandwidths: ['34.05', '40.31', '68.77'] Mbps
#   Latencies:  ['22.82', '8.82', '5.97'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 77
#   Bandwidths: ['64.48', '37.06', '53.98'] Mbps
#   Latencies:  ['7.75', '13.86', '5.24'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 78
#   Bandwidths: ['17.79', '94.11', '72.70'] Mbps
#   Latencies:  ['16.95', '15.81', '8.09'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 79
#   Bandwidths: ['39.63', '48.62', '28.23'] Mbps
#   Latencies:  ['14.22', '12.00', '16.41'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 80
#   Bandwidths: ['71.50', '56.78', '32.89'] Mbps
#   Latencies:  ['13.39', '20.49', '7.40'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 81
#   Bandwidths: ['46.63', '34.68', '77.34'] Mbps
#   Latencies:  ['21.39', '5.38', '22.31'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 82
#   Bandwidths: ['25.76', '59.99', '44.98'] Mbps
#   Latencies:  ['22.56', '15.90', '13.36'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 83
#   Bandwidths: ['56.15', '50.89', '27.47'] Mbps
#   Latencies:  ['9.67', '15.55', '6.54'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 84
#   Bandwidths: ['55.40', '53.28', '57.12'] Mbps
#   Latencies:  ['21.33', '5.55', '17.72'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 85
#   Bandwidths: ['54.80', '76.71', '84.55'] Mbps
#   Latencies:  ['17.02', '13.93', '18.10'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 86
#   Bandwidths: ['80.42', '58.25', '25.34'] Mbps
#   Latencies:  ['21.33', '16.77', '18.54'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 87
#   Bandwidths: ['30.59', '41.03', '70.25'] Mbps
#   Latencies:  ['18.78', '7.66', '7.47'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 88
#   Bandwidths: ['62.82', '82.79', '30.01'] Mbps
#   Latencies:  ['11.43', '21.06', '16.40'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 89
#   Bandwidths: ['35.57', '49.98', '35.14'] Mbps
#   Latencies:  ['22.47', '20.27', '16.13'] ms
#   Server Loads: ['0.01', '0.01', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 90
#   Bandwidths: ['41.47', '71.72', '21.15'] Mbps
#   Latencies:  ['18.44', '16.77', '12.67'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 91
#   Bandwidths: ['39.59', '34.19', '38.05'] Mbps
#   Latencies:  ['17.77', '8.06', '6.57'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 92
#   Bandwidths: ['9.80', '38.12', '40.35'] Mbps
#   Latencies:  ['16.33', '8.54', '13.02'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 93
#   Bandwidths: ['49.56', '39.29', '77.70'] Mbps
#   Latencies:  ['19.75', '16.81', '8.58'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 94
#   Bandwidths: ['93.78', '29.58', '62.42'] Mbps
#   Latencies:  ['12.92', '20.56', '21.54'] ms
#   Server Loads: ['0.00', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 95
#   Bandwidths: ['64.52', '49.75', '26.02'] Mbps
#   Latencies:  ['10.38', '17.97', '16.61'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 96
#   Bandwidths: ['54.83', '29.97', '30.96'] Mbps
#   Latencies:  ['13.42', '6.98', '22.16'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 97
#   Bandwidths: ['38.12', '41.30', '41.25'] Mbps
#   Latencies:  ['13.45', '22.11', '11.58'] ms
#   Server Loads: ['0.00', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 98
#   Bandwidths: ['38.65', '40.31', '49.08'] Mbps
#   Latencies:  ['21.43', '17.33', '19.41'] ms
#   Server Loads: ['0.02', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 99
#   Bandwidths: ['123.58', '29.83', '48.59'] Mbps
#   Latencies:  ['14.76', '23.03', '22.55'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0

# %% [markdown]
# <h1>256x256 Output Model Simulation With Next Generation Hardware</h1>

# %%
main(25, 'next', '256')
# Out:
# --- Simulation: Next Gen | Model 256 | Size: 25KB ---
#
# Step: 0
#   Bandwidths: ['23.37', '99.73', '67.30'] Mbps
#   Latencies:  ['5.83', '5.58', '3.09'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 1
#   Bandwidths: ['49.92', '46.90', '34.34'] Mbps
#   Latencies:  ['3.45', '4.24', '5.37'] ms
#   Server Loads: ['0.01', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 2
#   Bandwidths: ['27.52', '51.04', '91.74'] Mbps
#   Latencies:  ['1.89', '3.97', '4.33'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 3
#   Bandwidths: ['97.04', '67.51', '52.98'] Mbps
#   Latencies:  ['4.88', '3.95', '5.94'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 4
#   Bandwidths: ['114.64', '33.37', '20.79'] Mbps
#   Latencies:  ['3.16', '3.63', '2.76'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 5
#   Bandwidths: ['32.07', '58.24', '50.40'] Mbps
#   Latencies:  ['5.79', '3.62', '5.86'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 6
#   Bandwidths: ['22.25', '37.77', '53.02'] Mbps
#   Latencies:  ['1.73', '4.77', '4.87'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 7
#   Bandwidths: ['50.54', '48.12', '34.39'] Mbps
#   Latencies:  ['3.75', '5.50', '4.52'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 8
#   Bandwidths: ['117.56', '23.14', '13.20'] Mbps
#   Latencies:  ['5.40', '3.37', '4.67'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 9
#   Bandwidths: ['51.99', '60.06', '15.65'] Mbps
#   Latencies:  ['5.26', '4.01', '3.64'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 10
#   Bandwidths: ['25.57', '30.90', '101.24'] Mbps
#   Latencies:  ['2.70', '3.34', '6.12'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 11
#   Bandwidths: ['23.94', '66.49', '21.01'] Mbps
#   Latencies:  ['4.35', '4.78', '5.51'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 12
#   Bandwidths: ['95.50', '68.64', '34.98'] Mbps
#   Latencies:  ['2.66', '4.59', '4.28'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 13
#   Bandwidths: ['55.72', '31.42', '61.19'] Mbps
#   Latencies:  ['1.82', '2.48', '5.40'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 14
#   Bandwidths: ['32.09', '36.42', '39.45'] Mbps
#   Latencies:  ['5.92', '5.54', '3.31'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 15
#   Bandwidths: ['80.05', '62.89', '50.35'] Mbps
#   Latencies:  ['2.75', '3.31', '3.64'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 16
#   Bandwidths: ['32.15', '22.31', '63.87'] Mbps
#   Latencies:  ['3.60', '6.25', '4.58'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 17
#   Bandwidths: ['65.46', '72.58', '55.02'] Mbps
#   Latencies:  ['4.37', '5.11', '6.04'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 18
#   Bandwidths: ['108.91', '117.82', '89.41'] Mbps
#   Latencies:  ['1.85', '2.90', '6.00'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 19
#   Bandwidths: ['40.54', '20.32', '65.46'] Mbps
#   Latencies:  ['4.99', '2.41', '6.26'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 20
#   Bandwidths: ['29.88', '60.44', '32.80'] Mbps
#   Latencies:  ['3.16', '6.21', '6.18'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 21
#   Bandwidths: ['32.22', '77.72', '26.94'] Mbps
#   Latencies:  ['5.87', '4.74', '3.96'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 22
#   Bandwidths: ['34.38', '40.24', '30.06'] Mbps
#   Latencies:  ['2.33', '3.58', '5.61'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 23
#   Bandwidths: ['26.08', '57.48', '73.14'] Mbps
#   Latencies:  ['5.38', '2.52', '4.02'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 24
#   Bandwidths: ['58.76', '52.69', '34.02'] Mbps
#   Latencies:  ['3.10', '4.17', '6.17'] ms
#   Server Loads: ['0.01', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 25
#   Bandwidths: ['25.79', '21.01', '68.35'] Mbps
#   Latencies:  ['4.20', '6.17', '5.40'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 26
#   Bandwidths: ['42.96', '21.92', '56.10'] Mbps
#   Latencies:  ['5.10', '1.80', '3.06'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 27
#   Bandwidths: ['34.71', '92.75', '85.04'] Mbps
#   Latencies:  ['3.65', '5.75', '5.67'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 28
#   Bandwidths: ['59.51', '39.95', '56.03'] Mbps
#   Latencies:  ['3.92', '4.75', '4.33'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 29
#   Bandwidths: ['62.17', '25.33', '104.75'] Mbps
#   Latencies:  ['4.13', '1.77', '2.38'] ms
#   Server Loads: ['0.01', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 30
#   Bandwidths: ['36.38', '23.93', '50.88'] Mbps
#   Latencies:  ['4.91', '5.34', '4.45'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 31
#   Bandwidths: ['59.38', '25.36', '52.05'] Mbps
#   Latencies:  ['5.10', '6.03', '3.46'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 32
#   Bandwidths: ['34.31', '21.83', '45.00'] Mbps
#   Latencies:  ['4.02', '4.75', '5.65'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 33
#   Bandwidths: ['43.02', '44.72', '27.28'] Mbps
#   Latencies:  ['4.99', '5.77', '4.64'] ms
#   Server Loads: ['0.01', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 34
#   Bandwidths: ['51.57', '51.47', '61.69'] Mbps
#   Latencies:  ['2.27', '3.65', '5.83'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 35
#   Bandwidths: ['46.12', '58.64', '96.11'] Mbps
#   Latencies:  ['4.19', '5.36', '4.67'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 36
#   Bandwidths: ['90.56', '42.34', '85.29'] Mbps
#   Latencies:  ['2.22', '5.25', '6.15'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 37
#   Bandwidths: ['70.86', '11.58', '59.09'] Mbps
#   Latencies:  ['2.41', '2.31', '6.13'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 38
#   Bandwidths: ['19.55', '70.84', '50.99'] Mbps
#   Latencies:  ['4.15', '4.51', '5.29'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 39
#   Bandwidths: ['39.86', '42.79', '46.46'] Mbps
#   Latencies:  ['1.77', '5.38', '3.49'] ms
#   Server Loads: ['0.01', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 40
#   Bandwidths: ['58.40', '41.53', '53.85'] Mbps
#   Latencies:  ['3.92', '2.93', '6.28'] ms
#   Server Loads: ['0.01', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 41
#   Bandwidths: ['48.58', '77.41', '61.75'] Mbps
#   Latencies:  ['1.90', '6.27', '6.19'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 42
#   Bandwidths: ['64.67', '35.30', '72.07'] Mbps
#   Latencies:  ['4.95', '2.82', '5.93'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 43
#   Bandwidths: ['52.55', '20.73', '59.60'] Mbps
#   Latencies:  ['1.94', '2.00', '4.37'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 44
#   Bandwidths: ['63.51', '41.01', '34.16'] Mbps
#   Latencies:  ['6.29', '4.25', '4.33'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 45
#   Bandwidths: ['117.51', '65.03', '49.10'] Mbps
#   Latencies:  ['5.01', '4.92', '5.33'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 46
#   Bandwidths: ['22.21', '63.84', '39.98'] Mbps
#   Latencies:  ['2.09', '5.11', '2.33'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 47
#   Bandwidths: ['51.72', '78.84', '52.67'] Mbps
#   Latencies:  ['4.60', '4.35', '2.80'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 48
#   Bandwidths: ['17.28', '26.80', '66.34'] Mbps
#   Latencies:  ['4.15', '6.27', '6.02'] ms
#   Server Loads: ['0.01', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 49
#   Bandwidths: ['43.98', '56.37', '72.32'] Mbps
#   Latencies:  ['1.78', '5.36', '5.06'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 50
#   Bandwidths: ['33.31', '31.64', '31.11'] Mbps
#   Latencies:  ['5.89', '2.70', '1.80'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 51
#   Bandwidths: ['34.31', '39.38', '63.38'] Mbps
#   Latencies:  ['6.30', '4.79', '4.10'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 52
#   Bandwidths: ['77.41', '49.81', '26.70'] Mbps
#   Latencies:  ['4.63', '2.51', '6.16'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 53
#   Bandwidths: ['36.55', '60.29', '27.81'] Mbps
#   Latencies:  ['2.80', '2.08', '3.03'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 54
#   Bandwidths: ['22.21', '45.48', '63.24'] Mbps
#   Latencies:  ['1.77', '2.82', '5.69'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 55
#   Bandwidths: ['75.94', '48.97', '71.24'] Mbps
#   Latencies:  ['2.14', '5.18', '3.05'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 56
#   Bandwidths: ['44.69', '46.67', '28.04'] Mbps
#   Latencies:  ['4.88', '3.24', '4.30'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 57
#   Bandwidths: ['34.93', '62.92', '50.07'] Mbps
#   Latencies:  ['3.25', '6.18', '4.22'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 58
#   Bandwidths: ['59.17', '70.37', '56.41'] Mbps
#   Latencies:  ['5.81', '3.65', '4.66'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 59
#   Bandwidths: ['27.31', '27.12', '51.10'] Mbps
#   Latencies:  ['5.89', '4.51', '3.31'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 60
#   Bandwidths: ['35.92', '57.83', '93.01'] Mbps
#   Latencies:  ['2.89', '4.39', '2.58'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 61
#   Bandwidths: ['66.72', '58.82', '32.21'] Mbps
#   Latencies:  ['3.33', '2.40', '2.08'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 62
#   Bandwidths: ['38.58', '34.75', '118.27'] Mbps
#   Latencies:  ['2.53', '6.14', '5.58'] ms
#   Server Loads: ['0.00', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 63
#   Bandwidths: ['70.16', '32.08', '37.99'] Mbps
#   Latencies:  ['4.88', '2.02', '2.28'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 64
#   Bandwidths: ['34.32', '55.60', '94.91'] Mbps
#   Latencies:  ['4.12', '2.58', '4.80'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 65
#   Bandwidths: ['24.62', '27.80', '32.46'] Mbps
#   Latencies:  ['2.83', '4.41', '5.14'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 66
#   Bandwidths: ['25.65', '49.90', '48.82'] Mbps
#   Latencies:  ['4.74', '4.26', '4.32'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 67
#   Bandwidths: ['39.72', '42.72', '30.93'] Mbps
#   Latencies:  ['3.08', '2.66', '5.96'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 68
#   Bandwidths: ['21.27', '29.79', '50.46'] Mbps
#   Latencies:  ['5.96', '4.63', '5.62'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 69
#   Bandwidths: ['90.79', '38.35', '43.25'] Mbps
#   Latencies:  ['2.59', '3.61', '6.22'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 70
#   Bandwidths: ['49.69', '41.29', '63.57'] Mbps
#   Latencies:  ['4.80', '3.25', '5.50'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 71
#   Bandwidths: ['43.22', '42.61', '18.55'] Mbps
#   Latencies:  ['4.46', '5.98', '5.72'] ms
#   Server Loads: ['0.01', '0.02', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 72
#   Bandwidths: ['48.50', '44.93', '104.46'] Mbps
#   Latencies:  ['4.12', '1.84', '6.15'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 73
#   Bandwidths: ['30.67', '35.17', '80.38'] Mbps
#   Latencies:  ['3.91', '3.87', '3.73'] ms
#   Server Loads: ['0.00', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 74
#   Bandwidths: ['12.47', '46.88', '69.67'] Mbps
#   Latencies:  ['3.51', '5.08', '4.35'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 75
#   Bandwidths: ['54.52', '20.04', '28.85'] Mbps
#   Latencies:  ['5.93', '4.59', '1.74'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 76
#   Bandwidths: ['55.07', '39.30', '21.99'] Mbps
#   Latencies:  ['4.16', '3.67', '5.98'] ms
#   Server Loads: ['0.02', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 77
#   Bandwidths: ['50.04', '40.23', '19.11'] Mbps
#   Latencies:  ['1.70', '4.42', '3.35'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 78
#   Bandwidths: ['30.23', '65.09', '36.42'] Mbps
#   Latencies:  ['4.23', '3.71', '2.84'] ms
#   Server Loads: ['0.02', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 79
#   Bandwidths: ['39.58', '28.17', '22.76'] Mbps
#   Latencies:  ['3.06', '4.67', '3.03'] ms
#   Server Loads: ['0.01', '0.00', '0.02']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 80
#   Bandwidths: ['55.92', '74.06', '62.87'] Mbps
#   Latencies:  ['4.12', '5.05', '5.54'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 81
#   Bandwidths: ['38.17', '29.89', '66.63'] Mbps
#   Latencies:  ['2.66', '3.28', '2.94'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 82
#   Bandwidths: ['42.81', '46.11', '41.45'] Mbps
#   Latencies:  ['2.99', '6.02', '5.43'] ms
#   Server Loads: ['0.00', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 83
#   Bandwidths: ['35.58', '61.37', '23.94'] Mbps
#   Latencies:  ['2.96', '4.96', '2.78'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 84
#   Bandwidths: ['39.70', '35.85', '52.13'] Mbps
#   Latencies:  ['6.02', '2.11', '6.04'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 85
#   Bandwidths: ['56.88', '40.72', '40.93'] Mbps
#   Latencies:  ['3.97', '5.98', '6.22'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 86
#   Bandwidths: ['42.65', '65.56', '63.59'] Mbps
#   Latencies:  ['6.21', '3.38', '3.99'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 87
#   Bandwidths: ['28.59', '44.83', '39.59'] Mbps
#   Latencies:  ['3.66', '3.27', '5.44'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 88
#   Bandwidths: ['36.15', '112.80', '50.24'] Mbps
#   Latencies:  ['4.16', '2.24', '2.96'] ms
#   Server Loads: ['0.00', '0.01', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 89
#   Bandwidths: ['52.16', '19.87', '23.33'] Mbps
#   Latencies:  ['6.28', '6.16', '4.95'] ms
#   Server Loads: ['0.02', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 90
#   Bandwidths: ['69.96', '64.46', '84.52'] Mbps
#   Latencies:  ['2.73', '1.79', '5.57'] ms
#   Server Loads: ['0.00', '0.02', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 91
#   Bandwidths: ['63.95', '47.06', '60.80'] Mbps
#   Latencies:  ['2.29', '2.20', '3.01'] ms
#   Server Loads: ['0.00', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 92
#   Bandwidths: ['84.70', '66.51', '54.93'] Mbps
#   Latencies:  ['5.69', '2.04', '2.25'] ms
#   Server Loads: ['0.00', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 93
#   Bandwidths: ['51.83', '20.52', '24.65'] Mbps
#   Latencies:  ['5.81', '3.34', '4.40'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 94
#   Bandwidths: ['53.68', '46.23', '67.16'] Mbps
#   Latencies:  ['2.79', '2.03', '3.37'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 1
#
# Step: 95
#   Bandwidths: ['83.41', '53.41', '75.17'] Mbps
#   Latencies:  ['2.64', '2.12', '3.62'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 96
#   Bandwidths: ['51.61', '66.96', '54.35'] Mbps
#   Latencies:  ['3.40', '1.72', '4.66'] ms
#   Server Loads: ['0.01', '0.02', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 97
#   Bandwidths: ['19.33', '17.76', '49.70'] Mbps
#   Latencies:  ['2.48', '3.77', '2.75'] ms
#   Server Loads: ['0.02', '0.01', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 0
#
# Step: 98
#   Bandwidths: ['21.75', '46.90', '40.79'] Mbps
#   Latencies:  ['2.48', '5.71', '4.22'] ms
#   Server Loads: ['0.01', '0.00', '0.01']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
#
# Step: 99
#   Bandwidths: ['36.79', '98.55', '35.43'] Mbps
#   Latencies:  ['4.94', '3.50', '4.76'] ms
#   Server Loads: ['0.01', '0.00', '0.00']
#   Queue Lengths: ['0.0', '0.0', '0.0']
#   ➤ Agent Action: OFFLOAD to Edge Server 2
